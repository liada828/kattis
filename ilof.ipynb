# %% [markdown]
# <a href="https://colab.research.google.com/github/liada828/kattis/blob/main/ilof.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pickle
import numpy as np
import pandas
import matplotlib.pyplot as plt
from google.colab import drive

drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/ilof/two_devices_data.pkl'

with open(file_path, 'rb') as f:
    data = pickle.load(f)
# Out:
# Mounted at /content/drive

# %%
print(data.keys())
# Out:
# dict_keys(['Probe', 'Backscat', 'Date', 'Label'])

# %%
data_frame=pandas.DataFrame.from_dict(data)

# %%
data_frame_c1 = data_frame[data_frame["Label"] == 'C1']
data_frame_c2 = data_frame[data_frame["Label"] == 'C2']
data_frame_c3 = data_frame[data_frame["Label"] == 'C3']
data_frame_c4 = data_frame[data_frame["Label"] == 'C4']
data_frame_c5 = data_frame[data_frame["Label"] == 'C5']
data_frame_c6 = data_frame[data_frame["Label"] == 'C6']
data_frame_c7 = data_frame[data_frame["Label"] == 'C7']

# %%
data_frame_c1_02 = data_frame_c1[data_frame_c1["Probe"]=='OZ02'].iloc[:,[1]].to_numpy()
data_frame_c2_02 = data_frame_c2[data_frame_c2["Probe"]=='OZ02'].iloc[:,[1]].to_numpy()
data_frame_c3_02 = data_frame_c3[data_frame_c3["Probe"]=='OZ02'].iloc[:,[1]].to_numpy()
data_frame_c4_02 = data_frame_c4[data_frame_c4["Probe"]=='OZ02'].iloc[:,[1]].to_numpy()
data_frame_c5_02 = data_frame_c5[data_frame_c5["Probe"]=='OZ02'].iloc[:,[1]].to_numpy()
data_frame_c6_02 = data_frame_c6[data_frame_c6["Probe"]=='OZ02'].iloc[:,[1]].to_numpy()
data_frame_c7_02 = data_frame_c7[data_frame_c7["Probe"]=='OZ02'].iloc[:,[1]].to_numpy()

data_frame_c1_03 = data_frame_c1[data_frame_c1["Probe"]=='OZ03'].iloc[:,[1]].to_numpy()
data_frame_c2_03 = data_frame_c2[data_frame_c2["Probe"]=='OZ03'].iloc[:,[1]].to_numpy()
data_frame_c3_03 = data_frame_c3[data_frame_c3["Probe"]=='OZ03'].iloc[:,[1]].to_numpy()
data_frame_c4_03 = data_frame_c4[data_frame_c4["Probe"]=='OZ03'].iloc[:,[1]].to_numpy()
data_frame_c5_03 = data_frame_c5[data_frame_c5["Probe"]=='OZ03'].iloc[:,[1]].to_numpy()
data_frame_c6_03 = data_frame_c6[data_frame_c6["Probe"]=='OZ03'].iloc[:,[1]].to_numpy()
data_frame_c7_03 = data_frame_c7[data_frame_c7["Probe"]=='OZ03'].iloc[:,[1]].to_numpy()

# %%
data_frame_c1_02_simp = np.zeros((5*5, 1500000))
data_frame_c2_02_simp = np.zeros((5*5, 1500000))
data_frame_c3_02_simp = np.zeros((5*5, 1500000))
data_frame_c4_02_simp = np.zeros((5*5, 1500000))
data_frame_c5_02_simp = np.zeros((5*5, 1500000))
data_frame_c6_02_simp = np.zeros((5*5, 1500000))
data_frame_c7_02_simp = np.zeros((5*5, 1500000))

data_frame_c1_03_simp = np.zeros((5*5, 1500000))
data_frame_c2_03_simp = np.zeros((5*5, 1500000))
data_frame_c3_03_simp = np.zeros((5*5, 1500000))
data_frame_c4_03_simp = np.zeros((5*5, 1500000))
data_frame_c5_03_simp = np.zeros((5*5, 1500000))
data_frame_c6_03_simp = np.zeros((5*5, 1500000))
data_frame_c7_03_simp = np.zeros((5*5, 1500000))

# %%
data_frame_c1_02_simp[0:5,:] = data_frame_c1_02[0][0]
for i in range(1,5):
  data_frame_c1_02_simp[5*i:(5*i+5),:] = data_frame_c1_02[i][0]

data_frame_c2_02_simp[0:5,:] = data_frame_c2_02[0][0]
for i in range(1,5):
  data_frame_c2_02_simp[5*i:(5*i+5),:] = data_frame_c2_02[i][0]

data_frame_c3_02_simp[0:5,:] = data_frame_c3_02[0][0]
for i in range(1,5):
  data_frame_c3_02_simp[5*i:(5*i+5),:] = data_frame_c3_02[i][0]

data_frame_c4_02_simp[0:5,:] = data_frame_c4_02[0][0]
for i in range(1,5):
  data_frame_c4_02_simp[5*i:(5*i+5),:] = data_frame_c4_02[i][0]

data_frame_c5_02_simp[0:5,:] = data_frame_c5_02[0][0]
for i in range(1,5):
  data_frame_c5_02_simp[5*i:(5*i+5),:] = data_frame_c5_02[i][0]

data_frame_c6_02_simp[0:5,:] = data_frame_c6_02[0][0]
for i in range(1,5):
  data_frame_c6_02_simp[5*i:(5*i+5),:] = data_frame_c6_02[i][0]

data_frame_c7_02_simp[0:5,:] = data_frame_c7_02[0][0]
for i in range(1,5):
  data_frame_c7_02_simp[5*i:(5*i+5),:] = data_frame_c7_02[i][0]

# %%
data_frame_c1_03_simp[0:5,:] = data_frame_c1_03[0][0][0:5,:]
for i in range(1,5):
  data_frame_c1_03_simp[5*i:(5*i+5),:] = data_frame_c1_03[i][0][0:5,:]

data_frame_c2_03_simp[0:5,:] = data_frame_c2_03[0][0][0:5,:]
for i in range(1,5):
  data_frame_c2_03_simp[5*i:(5*i+5),:] = data_frame_c2_03[i][0][0:5,:]

data_frame_c3_03_simp[0:5,:] = data_frame_c3_03[0][0][0:5,:]
for i in range(1,5):
  data_frame_c3_03_simp[5*i:(5*i+5),:] = data_frame_c3_03[i][0][0:5,:]

data_frame_c4_03_simp[0:5,:] = data_frame_c4_03[0][0][0:5,:]
for i in range(1,5):
  data_frame_c4_03_simp[5*i:(5*i+5),:] = data_frame_c4_03[i][0][0:5,:]

data_frame_c5_03_simp[0:5,:] = data_frame_c5_03[0][0][0:5,:]
for i in range(1,5):
  data_frame_c5_03_simp[5*i:(5*i+5),:] = data_frame_c5_03[i][0][0:5,:]

data_frame_c6_03_simp[0:5,:] = data_frame_c6_03[0][0][0:5,:]
for i in range(1,5):
  data_frame_c6_03_simp[5*i:(5*i+5),:] = data_frame_c6_03[i][0][0:5,:]

data_frame_c7_03_simp[0:5,:] = data_frame_c7_03[0][0][0:5,:]
for i in range(1,5):
  data_frame_c7_03_simp[5*i:(5*i+5),:] = data_frame_c7_03[i][0][0:5,:]

# %%
(n_c1_02, bin_c1_02, patch_c1_02) = plt.hist(data_frame_c1_02_simp[22,0:200000],5)
(n_c1_03, bin_c1_03, patch_c1_03) = plt.hist(data_frame_c1_03_simp[22,0:200000],5)

# %%
(n_c2_02, bin_c2_02, patch_c2_02) = plt.hist(data_frame_c2_02_simp[2,0:400000],5)
(n_c2_03, bin_c2_03, patch_c2_03) = plt.hist(data_frame_c2_03_simp[2,0:400000],5)

# %%
(n_c3_02, bin_c3_02, patch_c3_02) = plt.hist(data_frame_c3_02_simp[0,0:2000000],5)
(n_c3_03, bin_c3_03, patch_c3_03) = plt.hist(data_frame_c3_03_simp[0,0:2000000],5)

# %%
(n_c4_02, bin_c4_02, patch_c4_02) = plt.hist(data_frame_c4_02_simp[0,0:2000000],5)
(n_c4_03, bin_c4_03, patch_c4_03) = plt.hist(data_frame_c4_03_simp[0,0:2000000],5)

# %%
(n_c5_02, bin_c5_02, patch_c5_02) = plt.hist(data_frame_c5_02_simp[0,0:2000000],5)
(n_c5_03, bin_c5_03, patch_c5_03) = plt.hist(data_frame_c5_03_simp[0,0:2000000],5)

# %%
(n_c6_02, bin_c6_02, patch_c6_02) = plt.hist(data_frame_c6_02_simp[0,0:4000000],5)
(n_c6_03, bin_c6_03, patch_c6_03) = plt.hist(data_frame_c6_03_simp[0,0:4000000],5)

# %%
(n_c7_02, bin_c7_02, patch_c7_02) = plt.hist(data_frame_c7_02_simp[0,0:4000000],5)
(n_c7_03, bin_c7_03, patch_c7_03) = plt.hist(data_frame_c7_03_simp[0,0:4000000],5)

# %%
feature_vec = [n_c1_02/n_c1_02.sum(), n_c1_03/n_c1_03.sum(),
               n_c2_02/n_c2_02.sum(), n_c2_03/n_c2_03.sum(),
               n_c3_02/n_c3_02.sum(), n_c3_03/n_c3_03.sum(),
               n_c4_02/n_c4_02.sum(), n_c4_03/n_c4_03.sum(),
               n_c5_02/n_c5_02.sum(), n_c5_03/n_c5_03.sum(),
               n_c6_02/n_c6_02.sum(), n_c6_03/n_c6_03.sum(),
               n_c7_02/n_c7_02.sum(), n_c7_03/n_c7_03.sum(),]

# %%
similarity = np.zeros((14,14))
for i in range(0,14):
  for j in range(0,14):
    similarity[i,j] = np.linalg.norm((feature_vec[i] - feature_vec[j]),1)

# %%
for r in similarity:
   for c in r:
      print("{:.3f}".format(c),end = "   ")
   print()
# Out:
# 0.000   0.034   0.044   0.050   0.245   0.206   0.412   0.361   0.376   0.343   0.519   0.669   0.338   0.503
# 0.034   0.000   0.071   0.082   0.279   0.234   0.439   0.389   0.404   0.370   0.547   0.696   0.365   0.530
# 0.044   0.071   0.000   0.018   0.214   0.162   0.368   0.317   0.333   0.299   0.476   0.625   0.297   0.459
# 0.050   0.082   0.018   0.000   0.197   0.156   0.362   0.311   0.326   0.292   0.469   0.618   0.287   0.453
# 0.245   0.279   0.214   0.197   0.000   0.104   0.235   0.183   0.197   0.163   0.340   0.491   0.157   0.325
# 0.206   0.234   0.162   0.156   0.104   0.000   0.207   0.155   0.170   0.137   0.313   0.463   0.154   0.297
# 0.412   0.439   0.368   0.362   0.235   0.207   0.000   0.053   0.081   0.087   0.109   0.257   0.110   0.091
# 0.361   0.389   0.317   0.311   0.183   0.155   0.053   0.000   0.046   0.038   0.159   0.308   0.061   0.143
# ...
